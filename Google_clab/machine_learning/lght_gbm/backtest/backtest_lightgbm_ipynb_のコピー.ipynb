# %% [markdown]
# <a href="https://colab.research.google.com/github/SuzukiRyotaro1998/stock_AI/blob/main/Google_clab/machine_learning/lght_gbm/backtest/backtest_lightgbm_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
import pandas as pd
import numpy as np
import tensorflow as tf
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
import joblib
import operator
# visualize
import matplotlib.pyplot as plt
import matplotlib.style as style
from matplotlib_venn import venn2, venn3
import seaborn as sns
from matplotlib import pyplot
from matplotlib.ticker import ScalarFormatter

# !pip install yfinance
import statistics
# N-Lags model check
import yfinance as yf


# 他ファイルのインポート・リロード------------------------
import imp
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.63)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.6.3)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)

# %%
def prediction_csv(model,model_name,cols):


  #全時系列データの呼び出し
  model_stock = 'sandp500'
  path = '/content/drive/MyDrive/stock_data/stock_code/{}.csv'.format(model_stock)
  data = pd.read_csv(path)
  print(data)




  # # 作業ディレクトリの移動と確認------------------------
  os.chdir('/content/drive/MyDrive/machine_learning/data_preprocess/')
  # !ls
  # 他ファイルのインポート・リロード------------------------
  import data_process
  imp.reload(data_process)

  position = pd.DataFrame()
  count = 0
  for  file in data['symbol'] :
    count = count +1
    print(count)
    print(file)
    try:
      df = yf.download(file, start='2019-01-01')
      df = data_process.create_data(df)
      print(df)
      df[file] = model.predict(df[cols])
      print(df[file])
      position = pd.concat([position ,df[file] ],axis = 1)

    except: 
      print('errror')
      continue
  position.to_csv('/content/drive/MyDrive/machine_learning/light_gbm/backtest/prediction_{}_2.csv'.format(model_name))

# %%
def result1(percentChange):
    gains = 0
    numGains = 0
    losses = 0
    numLosses = 0
    for i in percentChange:
        if i > 0:
            gains += i
            numGains += 1
        elif i < 0:
            losses += i
            numLosses += 1
     

    total_return = statistics.mean(percentChange)

    if numGains > 0:
        average_gain = gains / numGains
        max_return = max(percentChange)
    else:
        average_gain = np.nan
        max_return = np.nan

    if numLosses > 0:
        average_loss = losses / numLosses
        max_loss = min(percentChange)
    else:
        average_loss = np.nan
        max_loss = np.nan

    if numGains > 0 and numLosses > 0:
        risk_reward_ratio = - average_gain / average_loss

    elif numGains == 0 and numLosses > 0:
        risk_reward_ratio = 0

    elif numGains > 0 and numLosses == 0:
        risk_reward_ratio = average_gain

    else:
        risk_reward_ratio = np.nan

    if numGains > 0 or numLosses > 0:
        batting_ave = numGains / (numGains + numLosses)
    else:
        batting_ave = np.nan


    return [total_return, average_gain, average_loss, max_return, max_loss, risk_reward_ratio, batting_ave]


def show_results(results):
    labels = ['average Return', 'Average Gain', 'Average Loss', 'Max Return', 'Max Loss', 'Risk Reward Ratio', 'Batting Average']
    for i in range(len(results)):
        print('%30s | %8.3f' % (labels[i], results[i]))

# %%
def backtest(model_list, model_name_list,cols):

  # model1,
  for model, model_name in zip(model_list, model_name_list):
    print(model_name)
    #予測値を作成　一度やったら飛ばす モデルを変えたらもう一度やる
    prediction_csv(model,model_name,cols)

    #いくつの銘柄を買うのか
    pickup = 3


    df = pd.read_csv('/content/drive/MyDrive/machine_learning/light_gbm/backtest/prediction_{}_2.csv'.format(model_name), index_col=0)
    print(df.tail)
    today_prediction = df.iloc[-1]
    # today_prediction = df.iloc[-2]
    today_prediction = today_prediction.sort_values(ascending=False) 
    # print(today_prediction)
    code_list = today_prediction.index.values.tolist()
    point_list = today_prediction.values.tolist()
    print(df.index[-1])
    print(code_list[0:10])
    print(point_list[0:10])


    # today_prediction = df.loc['2021-07-01 00:00:00']
    for i in range(-15,-1):
      today_prediction = df.iloc[i]
      # today_prediction = df.iloc[-2]
      today_prediction = today_prediction.sort_values(ascending=False) 
      # print(today_prediction)
      code_list = today_prediction.index.values.tolist()
      point_list = today_prediction.values.tolist()
      print(df.index[i])
      print(code_list[0:10])
      print(point_list[0:10])


   


    # df = df['2020-01-02 00:00:00':'2020-12-31 00:00:00']
    df = df.iloc[:-5]
    df = df['2021-01-04 00:00:00':]
    print(df)
    # df = df.drop('VAR.csv', axis=1)
    percent = []
    percentChange = []
    sell_prices =[]
    df.dropna(how='all')

    for i in range(0,len(df),5):
      series = df.iloc[i]
      series = series.sort_values(ascending=False) 
      code_list = series.index.values.tolist()
      point_list = series.values.tolist()
      date = df.index[i]
      print(date)
      print(code_list[0:pickup])
      print(point_list[0:pickup])


      for k in code_list[0:pickup]:
        data = yf.download(k.replace('.csv', ''), start="2020-01-01")
        shift_data1 = data.shift(-1)
        shift_data2 = data.shift(-6)

        # print(data[0:20])
        # print(shift_data1[0:20])
        # print(shift_data2[0:20])

        buy_price = shift_data1['Open'][date]
        sell_price = shift_data2['Open'][date]
      
        print('買値は'+str(buy_price))
        print('売値は'+str(sell_price))

        # stock_return = 100*(shift_data['Adj Close'][date]/data['Adj Close'][date]-1)
        stock_return = 100*(shift_data2['Open'][date]/shift_data1['Open'][date]-1)


        #損切りを付け加える
        if  stock_return < -15:
          stock_return = -16

        percent.append(stock_return)
      print('今回のリターン')
      print(percent)
      results = result1(percent)
      show_results(results)
      percent.clear()
      percentChange.append(results[0])

    print(percentChange)

    # print(percentChange)
    index = ['Total return', 'Average Gain', 'Average Loss', 'Max return' ,'Max Loss','Risk Reward Ratio', 'batting_average']
    results = result1(percentChange)
    print(results)
    show_results(results)

    print('========================')
    #     print(total_result.mean(axis='columns'))

    total_return = 1
    for m in percentChange:
        total_return = total_return * (1+m/100)

    print('最終リターンは'+ str((total_return - 1)*100))






cols =['return','sma210'

          ,'ratio_sma75_30', 'ratio_sma75_150', 'ratio_sma105_30', 
          'ratio_sma105_150', 'ratio_sma135_150'
          ,'Highest161','adosc', 'sma10', 
        'adosc-SG' ,'typical-price',"ema270"
      ,'Highest121','Highest45,81days_ago',

'today_by_sma30ratio','today_by_sma45ratio','today_by_sma60ratio','today_by_sma120ratio'
,'Adjclose_today_20daysago_ratio','Adjclose_today_15daysago_ratio','Adjclose_today_10daysago_ratio','Adjclose_today_5daysago_ratio',
          ]


# load model from file
model_name1 = 'XGBboost2'
model1 = joblib.load("/content/drive/MyDrive/machine_learning/XGBoost/model1/{}".format(model_name1))

model_name2 = 'lightgbm_best'
# model2 = joblib.load("/content/drive/MyDrive/machine_learning/light_gbm/model/{}.joblib".format(model_name2))
#
model2 = joblib.load("/content/drive/MyDrive/machine_learning/light_gbm/model/lightgbm_best.joblib ")
model_name_list = [model_name2]
model_list = [model2]

backtest(model_list, model_name_list,cols)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# 2021-07-12  154.399994  ...                 0.319596
# 2021-07-13  153.779999  ...                 0.529901
# 2021-07-14  153.750000  ...                 0.651843
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    7.034347
# 2019-01-03    0.753964
# 2019-01-04    0.753964
# 2019-01-07    0.753964
# 2019-01-08    4.547210
#                 ...
# 2021-07-08    4.272089
# 2021-07-09    4.100118
# 2021-07-12    4.091480
# 2021-07-13    4.092056
# 2021-07-14    3.981520
# Name: PKI, Length: 638, dtype: float64
# 365
# PRGO
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  38.500000  ...                      NaN
# 2019-01-03  40.939999  ...                      NaN
# 2019-01-04  40.290001  ...                      NaN
# 2019-01-07  42.419998  ...                      NaN
# 2019-01-08  44.470001  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  46.750000  ...                 1.933856
# 2021-07-09  46.950001  ...                 1.141280
# 2021-07-12  46.720001  ...                 0.969760
# 2021-07-13  46.230000  ...                 1.100678
# 2021-07-14  47.700001  ...                 1.932155
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    7.034347
# 2019-01-03    4.547210
# 2019-01-04    4.547210
# 2019-01-07    4.452176
# 2019-01-08    3.925735
#                 ...
# 2021-07-08    3.702308
# 2021-07-09    3.673917
# 2021-07-12    3.989476
# 2021-07-13    3.742365
# 2021-07-14    3.798009
# Name: PRGO, Length: 638, dtype: float64
# 366
# PFE
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  40.910816  ...                      NaN
# 2019-01-03  41.024670  ...                      NaN
# 2019-01-04  40.265656  ...                      NaN
# 2019-01-07  40.863377  ...                      NaN
# 2019-01-08  41.328274  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  39.000000  ...                 0.573014
# 2021-07-09  39.529999  ...                 0.285594
# 2021-07-12  39.660000  ...                 0.521725
# 2021-07-13  39.770000  ...                 0.192593
# 2021-07-14  39.720001  ...                 0.266192
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.423529
# 2019-01-03    0.163011
# 2019-01-04   -0.032817
# 2019-01-07    0.346298
# 2019-01-08    0.197929
#                 ...
# 2021-07-08    0.030896
# 2021-07-09    0.425390
# 2021-07-12    0.318692
# 2021-07-13    0.238464
# 2021-07-14    0.165557
# Name: PFE, Length: 638, dtype: float64
# 367
# PM
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  66.129997  ...                      NaN
# 2019-01-03  67.019997  ...                      NaN
# 2019-01-04  67.029999  ...                      NaN
# 2019-01-07  69.190002  ...                      NaN
# 2019-01-08  67.680000  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  98.169998  ...                 0.715777
# 2021-07-09  99.370003  ...                 0.935415
# 2021-07-12  98.889999  ...                 1.264428
# 2021-07-13  98.309998  ...                 1.384933
# 2021-07-14  98.000000  ...                 0.747230
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.547796
# 2019-01-03    0.685149
# 2019-01-04    3.983001
# 2019-01-07    0.663825
# 2019-01-08    0.625240
#                 ...
# 2021-07-08    2.980929
# 2021-07-09    2.942501
# 2021-07-12    3.105905
# 2021-07-13    3.071190
# 2021-07-14    3.000057
# Name: PM, Length: 638, dtype: float64
# 368
# PSX
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  85.320000  ...                      NaN
# 2019-01-03  88.180000  ...                      NaN
# 2019-01-04  88.449997  ...                      NaN
# 2019-01-07  90.610001  ...                      NaN
# 2019-01-08  92.290001  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  80.379997  ...                 0.439238
# 2021-07-09  81.599998  ...                 0.394764
# 2021-07-12  81.400002  ...                 0.605527
# 2021-07-13  81.809998  ...                 0.804674
# 2021-07-14  81.489998  ...                 1.584775
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    7.034347
# 2019-01-03    4.547210
# 2019-01-04    4.365699
# 2019-01-07    3.881400
# 2019-01-08    3.981884
#                 ...
# 2021-07-08   -0.628742
# 2021-07-09   -0.389194
# 2021-07-12   -0.377853
# 2021-07-13   -0.661633
# 2021-07-14   -0.569280
# Name: PSX, Length: 638, dtype: float64
# 369
# PNW
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  85.050003  ...                      NaN
# 2019-01-03  83.019997  ...                      NaN
# 2019-01-04  83.110001  ...                      NaN
# 2019-01-07  84.309998  ...                      NaN
# 2019-01-08  84.400002  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  83.220001  ...                 0.858546
# 2021-07-09  83.379997  ...                 0.795997
# 2021-07-12  83.190002  ...                 0.338562
# 2021-07-13  83.809998  ...                 0.337171
# 2021-07-14  82.940002  ...                 0.856463
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    2.728923
# 2019-01-03    0.677486
# 2019-01-04    3.975327
# 2019-01-07    4.225990
# 2019-01-08    3.972145
#                 ...
# 2021-07-08    3.367794
# 2021-07-09    3.509774
# 2021-07-12    3.606218
# 2021-07-13    3.296653
# 2021-07-14    3.322546
# Name: PNW, Length: 638, dtype: float64
# 370
# PXD
# [*********************100%***********************]  1 of 1 completed
#                   Open  ...  Volume_161daysago_ratio
# Date                    ...
# 2019-01-02  128.779999  ...                      NaN
# 2019-01-03  134.970001  ...                      NaN
# 2019-01-04  137.880005  ...                      NaN
# 2019-01-07  139.529999  ...                      NaN
# 2019-01-08  144.429993  ...                      NaN
# ...                ...  ...                      ...
# 2021-07-08
# [*********************100%***********************]  1 of 1 completed
#                   Open  ...  Volume_161daysago_ratio
# Date                    ...
# 2019-01-02   72.930000  ...                      NaN
# 2019-01-03   73.599998  ...                      NaN
# 2019-01-04   72.779999  ...                      NaN
# 2019-01-07   74.169998  ...                      NaN
# 2019-01-08   75.540001  ...                      NaN
# ...                ...  ...                      ...
# 2021-07-08  128.059998  ...                 1.194075
# 2021-07-09  129.600006  ...                 0.831749
# 2021-07-12  132.000000  ...                 0.554754
# 2021-07-13  134.080002  ...                 0.473473
# 2021-07-14  133.350006  ...                 0.610508
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.939313
# 2019-01-03    0.753964
# 2019-01-04    0.625240
# 2019-01-07    4.452176
# 2019-01-08    4.491956
#                 ...
# 2021-07-08    3.893837
# 2021-07-09    3.907598
# 2021-07-12    3.886128
# 2021-07-13    3.970276
# 2021-07-14    3.871532
# Name: RJF, Length: 638, dtype: float64
# 390
# RTX
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  66.179985  ...                      NaN
# 2019-01-03  67.684074  ...                      NaN
# 2019-01-04  65.525490  ...                      NaN
# 2019-01-07  67.375710  ...                      NaN
# 2019-01-08  68.495911  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  84.599998  ...                 0.683670
# 2021-07-09  86.500000  ...                 0.353434
# 2021-07-12  85.559998  ...                 0.490776
# 2021-07-13  86.169998  ...                 0.343055
# 2021-07-14  85.180000  ...                 0.402752
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.569900
# 2019-01-03    4.547210
# 2019-01-04    4.469747
# 2019-01-07    4.452176
# 2019-01-08    4.367134
#                 ...
# 2021-07-08    2.728352
# 2021-07-09    2.622349
# 2021-07-12    2.895453
# 2021-07-13    2.807961
# 2021-07-14    3.035044
# Name: RTX, Length: 638, dtype: float64
# 391
# O
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2018-12-31        NaN  ...                      NaN
# 2019-01-02  62.610001  ...                      NaN
# 2019-01-03  62.000000  ...                      NaN
# 2019-01-04  62.619999  ...                      NaN
# 2019-01-07  62.470001  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  67.949997  ...                 1.835900
# 2021-07-09  68.230003  ...                 1.014363
# 2021-07-12  68.699997  ...                 1.066677
# 2021-07-13  69.129997  ...                 0.963346
# 2021-07-14  68.379997  ...                 0.806514
#
# [639 rows x 215 columns]
# Date
# 2018-12-31    1.923292
# 2019-01-02    2.398045
# 2019-01-03    0.823301
# 2019-01-04    0.663825
# 2019-01-07    0.766624
#                 ...
# 2021-07-08   -0.082316
# 2021-07-09    0.201136
# 2021-07-12    0.230572
# 2021-07-13    0.158782
# 2021-07-14    0.089364
# Name: O, Length: 639, dtype: float64
# 392
# REG
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  58.290001  ...                      NaN
# 2019-01-03  56.790001  ...                      NaN
# 2019-01-04  57.139999  ...                      NaN
# 2019-01-07  57.220001  ...                      NaN
# 2019-01-08  57.840000  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  62.610001  ...                 1.113821
# 2021-07-09  64.050003  ...                 0.403043
# 2021-07-12  64.650002  ...                 0.958028
# 2021-07-13  66.690002  ...                 0.601142
# 2021-07-14  64.800003  ...                 0.688318
#
# [638 rows x 215 columns]
# Date
# 2019-01-02
# [*********************100%***********************]  1 of 1 completed
#                   Open  ...  Volume_161daysago_ratio
# Date                    ...
# 2019-01-02  111.989998  ...                      NaN
# 2019-01-03  110.930000  ...                      NaN
# 2019-01-04  108.190002  ...                      NaN
# 2019-01-07  110.339996  ...                      NaN
# 2019-01-08  112.000000  ...                      NaN
# ...                ...  ...                      ...
# 2021-07-08  249.929993  ...                 1.741814
# 2021-07-09  249.929993  ...                 2.029958
# 2021-07-12  248.070007  ...                 1.167618
# 2021-07-13  249.550003  ...                 1.223708
# 2021-07-14  247.490005  ...                 1.810574
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    2.438850
# 2019-01-03    0.089081
# 2019-01-04    0.089081
# 2019-01-07    0.163272
# 2019-01-08    0.149554
#                 ...
# 2021-07-08    4.085645
# 2021-07-09    4.129819
# 2021-07-12    3.882856
# 2021-07-13    3.798563
# 2021-07-14    3.790047
# Name: RMD, Length: 638, dtype: float64
# 397
# RHI
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  56.320000  ...                      NaN
# 2019-01-03  55.549999  ...                      NaN
# 2019-01-04  53.919998  ...                      NaN
# 2019-01-07  55.910000  ...                      NaN
# 2019-01-08  56.740002  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  86.180000  ...                 1.293076
# 2021-07-09  87.830002  ...                 0.761222
# 2021-07-12  87.739998  ...                 0.692414
# 2021-07-13  88.070000  ...                 0.851380
# 2021-07-14  87.290001  ...                 0.392368
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.998487
# 2019-01-03    0.753964
# 2019-01-04    0.625240
# 2019-01-07    4.547210
# 2019-01-08    4.517824
#                 ...
# 2021-07-08    2.524135
# 2021-07-09    2.799285
# 2021-07-12    2.634921
# 2021-07-13    2.518286
# 2021-07-14    2.486825
# Name: RHI, Length: 638, dtype: float64
# 398
# ROK
# [*********************100%***********************]  1 of 1 completed
#                   Open  ...  Volume_161daysago_ratio
# Date                    ...
# 2019-01-02  148.520004  ...                      NaN
# 2019-01-03  149.360001  ...                      NaN
# 2019-01-04  148.199997  ...                      NaN
# 2019-01-07  150.399994  ...                      NaN
# 2019-01-08  152.199997  ...                      NaN
# ...                ...  ...                      ...
# 2021-07-08  285.320007  ...                 0.621337
# 2021-07-09  291.880005  ...                 0.469649
# 2021-07-12  290.500000  ...                 0.571041
# 2021-07-13  292.890015  ...                 0.457410
# 2021-07-14  292.089996  ...                 0.531918
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.429884
# 2019-01-03    0.089081
# 2019-01-04    3.816405
# 2019-01-07    3.818035
# 2019-01-08    3.807877
#                 ...
# 2021-07-08    4.207243
# 2021-07-09    4.110919
# 2021-07-12    4.049114
# 2021-07-13    4.174160
# 2021-07-14    4.044008
# Name: ROK, Length: 638, dtype: float64
# 399
# ROL
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  23.833332  ...                      NaN
# 2019-01-03  23.773333  ...                      NaN
# 2019-01-04  23.853333  ...                      NaN
# 2019-01-07  24.273333  ...                      NaN
# 2019-01-08  24.646667  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  35.180000  ...                 0.958832
# 2021-07-09  35.230000  ...                 0.549038
# 2021-07-12  35.369999  ...                 0.748067
# 2021-07-13  35.299999  ...                 0.684204
# 2021-07-14  35.439999  ...                 0.737843
#
# [638 rows x 215 columns]
# Date
# 2019-01-02
# [*********************100%***********************]  1 of 1 completed
#                   Open  ...  Volume_161daysago_ratio
# Date                    ...
# 2019-01-02  133.399994  ...                      NaN
# 2019-01-03  133.479996  ...                      NaN
# 2019-01-04  133.500000  ...                      NaN
# 2019-01-07  141.020004  ...                      NaN
# 2019-01-08  144.729996  ...                      NaN
# ...                ...  ...                      ...
# 2021-07-08  244.839996  ...                 0.999922
# 2021-07-09  245.589996  ...                 0.737160
# 2021-07-12  247.220001  ...                 1.100929
# 2021-07-13  242.289993  ...                 1.138985
# 2021-07-14  244.500000  ...                 0.783580
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.539951
# 2019-01-03    0.089081
# 2019-01-04    3.904691
# 2019-01-07    3.854817
# 2019-01-08    3.807877
#                 ...
# 2021-07-08    4.345000
# 2021-07-09    4.216724
# 2021-07-12    4.216658
# 2021-07-13    4.081268
# 2021-07-14    4.089711
# Name: CRM, Length: 638, dtype: float64
# 405
# SBAC
# [*********************100%***********************]  1 of 1 completed
#                   Open  ...  Volume_161daysago_ratio
# Date                    ...
# 2019-01-02  160.100006  ...                      NaN
# 2019-01-03  160.149994  ...                      NaN
# 2019-01-04  162.970001  ...                      NaN
# 2019-01-07  163.710007  ...                      NaN
# 2019-01-08  165.610001  ...                      NaN
# ...                ...  ...                      ...
# 2021-07-08  329.910004  ...                 1.639657
# 2021-07-09  328.910004  ...                 0.737478
# 2021-07-12  329.369995  ...                 0.958423
# 2021-07-13  330.489990  ...                 0.842701
# 2021-07-14  329.399994  ...                 0.774354
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.491325
# 2019-01-03    3.818035
# 2019-01-04    3.904691
# 2019-01-07    3.854817
# 2019-01-08    3.817253
#                 ...
# 2021-07-08    3.790027
# 2021-07-09    3.886898
# 2021-07-12    3.823576
# 2021-07-13    3.878713
# 2021-07-14    3.886093
# Name: SBAC, Length: 638, dtype: float64
# 406
# SLB
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  35.490002  ...                      NaN
# 2019-01-03  37.310001  ...                      NaN
# 2019-01-04  38.299999  ...                      NaN
# 2019-01-07  39.209999  ...                      NaN
# 2019-01-08  40.770000  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  29.959999  ...                 0.955114
# 2021-07-09  31.000000  ...                 0.370089
# 2021-07-12  30.770000  ...                 0.415080
# 2021-07-13  30.920000  ...                 0.529812
# 2021-07-14  30.980000  ...                 0.959052
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    7.034347
# 2019-01-03    4.547210
# 2019-01-04    4.547210
# 2019-01-07    4.491956
# 2019-01-08    4.469747
#                 ...
# 2021-07-08   -0.930766
# 2021-07-09   -0.759215
# 2021-07-12    0.008003
# 2021-07-13   -1.061574
# 2021-07-14   -0.776692
# Name: SLB, Length: 638, dtype: float64
# 407
# STX
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  37.919998  ...                      NaN
# 2019-01-03  38.610001  ...                      NaN
# 2019-01-04  37.180000  ...                      NaN
# 2019-01-07  38.369999  ...                      NaN
# 2019-01-08  39.450001  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  85.010002  ...                 0.720759
# 2021-07-09  87.540001  ...                 0.443190
# 2021-07-12  88.449997  ...                 0.627186
# 2021-07-13  88.010002  ...                 0.633716
# 2021-07-14  89.500000  ...                 0.770384
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.988647
# 2019-01-03    0.753964
# 2019-01-04    4.547210
# 2019-01-07    4.461930
# 2019-01-08    3.912236
#                 ...
# 2021-07-08    1.982502
# 2021-07-09    2.549611
# 2021-07-12    2.812773
# 2021-07-13    2.978221
# 2021-07-14    3.131505
# Name: STX, Length: 638, dtype: float64
# 408
# SEE
# [*********************100%***********************]  1 of 1 completed
#                  Open  ...  Volume_161daysago_ratio
# Date                   ...
# 2019-01-02  34.500000  ...                      NaN
# 2019-01-03  35.040001  ...                      NaN
# 2019-01-04  35.169998  ...                      NaN
# 2019-01-07  35.470001  ...                      NaN
# 2019-01-08  36.000000  ...                      NaN
# ...               ...  ...                      ...
# 2021-07-08  58.150002  ...                 1.526617
# 2021-07-09  58.930000  ...                 0.759617
# 2021-07-12  58.000000  ...                 0.928031
# 2021-07-13  58.020000  ...                 1.601077
# 2021-07-14  56.750000  ...                 0.967841
#
# [638 rows x 215 columns]
# Date
# 2019-01-02    6.284325
# 2019-01-03    4.452176
# 2019-01-04    4.479588
# 2019-01-07    4.469747
# 2019-01-08    3.943494
# ...
#                Batting Average |    1.000
# 2021-02-24 00:00:00
# ['RSG', 'KR', 'FOX']
# [5.119745595353566, 5.100569140751778, 4.823474952135592]
# [*********************100%***********************]  1 of 1 completed
# 買値は89.62000274658203
# 売値は91.3499984741211
# [*********************100%***********************]  1 of 1 completed
# 買値は32.95000076293945
# 売値は34.0
# [*********************100%***********************]  1 of 1 completed
# 買値は32.849998474121094
# 売値は37.06999969482422
# 今回のリターン
# [1.9303678582012207, 3.1866440447598787, 12.846275241162042]
#                 average Return |    5.988
#                   Average Gain |    5.988
#                   Average Loss |      nan
#                     Max Return |   12.846
#                       Max Loss |      nan
#              Risk Reward Ratio |    5.988
#                Batting Average |    1.000
# 2021-03-03 00:00:00
# ['MAS', 'KR', 'CHRW']
# [5.587742275418061, 5.397175002236747, 5.043515598222144]
# [*********************100%***********************]  1 of 1 completed
# 買値は53.119998931884766
# 売値は56.83000183105469
# [*********************100%***********************]  1 of 1 completed
# 買値は34.0
# 売値は35.279998779296875
# [*********************100%***********************]  1 of 1 completed
# 買値は92.87999725341797
# 売値は94.20999908447266
# 今回のリターン
# [6.984192345197937, 3.7647022920496376, 1.4319572247895929]
#                 average Return |    4.060
#                   Average Gain |    4.060
#                   Average Loss |      nan
#                     Max Return |    6.984
#                       Max Loss |      nan
#              Risk Reward Ratio |    4.060
#                Batting Average |    1.000
# 2021-03-10 00:00:00
# ['AKAM', 'BAX', 'INCY']
# [5.076987973257166, 4.8283823001191735, 4.827840054981054]
# [*********************100%***********************]  1 of 1 completed
# 買値は96.98999786376953
# 売値は98.95999908447266
# [*********************100%***********************]  1 of 1 completed
# 買値は77.63999938964844
# 売値は79.58999633789062
# [*********************100%***********************]  1 of 1 completed
# 買値は78.91000366210938
# 売値は79.36000061035156
# 今回のリターン
# [2.031138533965282, 2.511588051998581, 0.5702660339100607]
#                 average Return |    1.704
#                   Average Gain |    1.704
#                   Average Loss |      nan
#                     Max Return |    2.512
#                       Max Loss |      nan
#              Risk Reward Ratio |    1.704
#                Batting Average |    1.000
# 2021-03-17 00:00:00
# ['VZ', 'CMS', 'CAH']
# [5.0694102882090695, 4.823466072779599, 4.783031975516853]
# [*********************100%***********************]  1 of 1 completed
# 買値は55.75
# 売値は57.04999923706055
# [*********************100%***********************]  1 of 1 completed
# 買値は57.849998474121094
# 売値は61.209999084472656
# [*********************100%***********************]  1 of 1 completed
# 買値は57.810001373291016
# 売値は59.31999969482422
# 今回のリターン
# [2.3318371965211693, 5.808125668066588, 2.612001877984449]
#                 average Return |    3.584
#                   Average Gain |    3.584
#                   Average Loss |      nan
#                     Max Return |    5.808
#                       Max Loss |      nan
#              Risk Reward Ratio |    3.584
#                Batting Average |    1.000
# 2021-03-24 00:00:00
# ['PHM', 'BSX', 'MAS']
# [5.127519232072912, 5.078738083451625, 5.048587102332529]
# [*********************100%***********************]  1 of 1 completed
# 買値は47.4900016784668
# 売値は53.0
# [*********************100%***********************]  1 of 1 completed
# 買値は37.68000030517578
# 売値は38.61000061035156
# [*********************100%***********************]  1 of 1 completed
# 買値は57.540000915527344
# 売値は60.0
# 今回のリターン
# [11.602438675068694, 2.468153656166594, 4.275285097899295]
#                 average Return |    6.115
#                   Average Gain |    6.115
#                   Average Loss |      nan
#                     Max Return |   11.602
#                       Max Loss |      nan
#              Risk Reward Ratio |    6.115
#                Batting Average |    1.000
# 2021-03-31 00:00:00
# ['RCL', 'MAS', 'NLOK']
# [5.057030806335356, 5.048402418417028, 4.870853439433022]
# [*********************100%***********************]  1 of 1 completed
# 買値は86.5
# 売値は89.37999725341797
# [*********************100%***********************]  1 of 1 completed
# 買値は60.0
# 売値は61.689998626708984
# [*********************100%***********************]  1 of 1 completed
# 買値は21.420000076293945
# 売値は22.030000686645508
# 今回のリターン
# [3.3294765935467874, 2.8166643778483103, 2.847808628285975]
#                 average Return |    2.998
#                   Average Gain |    2.998
#                   Average Loss |      nan
#                     Max Return |    3.329
#                       Max Loss |      nan
#              Risk Reward Ratio |    2.998
#                Batting Average |    1.000
# 2021-04-08 00:00:00
# ['CMS', 'CHRW', 'BSX']
# [5.230747302086902, 5.182206339572552, 5.170491510388851]
# [*********************100%***********************]  1 of 1 completed
# 買値は60.54999923706055
# 売値は63.59000015258789
# [*********************100%***********************]  1 of 1 completed
# 買値は96.86000061035156
# 売値は101.37000274658203
# [*********************100%***********************]  1 of 1 completed
# 買値は38.77000045776367
# 売値は41.13999938964844
# 今回のリターン
# [5.020645671068258, 4.656207007857982, 6.112971121748267]
#                 average Return |    5.263
#                   Average Gain |    5.263
#                   Average Loss |      nan
#                     Max Return |    6.113
#                       Max Loss |      nan
#              Risk Reward Ratio |    5.263
#                Batting Average |    1.000
# 2021-04-15 00:00:00
# ['LNT', 'CMS', 'PRGO']
# [5.193248920508993, 5.130825315552809, 5.000880028606948]
# [*********************100%***********************]  1 of 1 completed
# 買値は56.04999923706055
# 売値は57.029998779296875
# [*********************100%***********************]  1 of 1 completed
# 買値は63.59000015258789
# 売値は64.55999755859375
# [*********************100%***********************]  1 of 1 completed
# 買値は41.310001373291016
# 売値は42.45000076293945
# 今回のリターン
# [1.7484381009381877, 1.5253929921029918, 2.759620798234841]
#                 average Return |    2.011
#                   Average Gain |    2.011
#                   Average Loss |      nan
#                     Max Return |    2.760
#                       Max Loss |      nan
#              Risk Reward Ratio |    2.011
#                Batting Average |    1.000
# 2021-04-22 00:00:00
# ['ROL', 'GNRC', 'SEE']
# [4.786073654049177, 4.77647130795034, 4.735174925005007]
# [*********************100%***********************]  1 of 1 completed
# 買値は35.38999938964844
# 売値は37.2599983215332
# [*********************100%***********************]  1 of 1 completed
# 買値は323.6499938964844
# 売値は333.9800109863281
# [*********************100%***********************]  1 of 1 completed
# 買値は48.25
# 売値は49.59000015258789
# 今回のリターン
# [5.283975598009594, 3.1917247905611568, 2.7772023887831843]
#                 average Return |    3.751
#                   Average Gain |    3.751
#                   Average Loss |      nan
#                     Max Return |    5.284
#                       Max Loss |      nan
#              Risk Reward Ratio |    3.751
#                Batting Average |    1.000
# 2021-04-29 00:00:00
# ['LNT', 'CNC', 'HRL']
# [5.3197897356253945, 5.1333360519969435, 5.122793372005236]
# [*********************100%***********************]  1 of 1 completed
# 買値は55.63999938964844
# 売値は56.189998626708984
# [*********************100%***********************]  1 of 1 completed
# 買値は60.41999816894531
# 売値は65.27999877929688
# [*********************100%***********************]  1 of 1 completed
# 買値は46.75
# 売値は47.369998931884766
# 今回のリターン
# [0.9884961234612577, 8.043695394961969, 1.3262009238176775]
#                 average Return |    3.453
#                   Average Gain |    3.453
#                   Average Loss |      nan
#                     Max Return |    8.044
#                       Max Loss |      nan
#              Risk Reward Ratio |    3.453
#                Batting Average |    1.000
# 2021-05-06 00:00:00
# ['CNC', 'ED', 'PRGO']
# [5.19933146389564, 4.931312646387106, 4.741888431967172]
# [*********************100%***********************]  1 of 1 completed
# 買値は65.27999877929688
# 売値は68.88999938964844
# [*********************100%***********************]  1 of 1 completed
# 買値は78.12000274658203
# 売値は79.61000061035156
# [*********************100%***********************]  1 of 1 completed
# 買値は42.689998626708984
# 売値は45.29999923706055
# 今回のリターン
# [5.530025548187445, 1.907319267003893, 6.11384561797248]
#                 average Return |    4.517
#                   Average Gain |    4.517
#                   Average Loss |      nan
#                     Max Return |    6.114
#                       Max Loss |      nan
#              Risk Reward Ratio |    4.517
#                Batting Average |    1.000
# 2021-05-13 00:00:00
# ['HRL', 'CNC', 'NEM']
# [5.2077559661369435, 5.152806121890336, 4.753023795234276]
# [*********************100%***********************]  1 of 1 completed
# 買値は47.349998474121094
# 売値は49.369998931884766
# [*********************100%***********************]  1 of 1 completed
# 買値は68.88999938964844
# 売値は72.12000274658203
# [*********************100%***********************]  1 of 1 completed
# 買値は69.61000061035156
# 売値は74.25
# 今回のリターン
# [4.266104588931907, 4.688638968719361, 6.665708014601623]
#                 average Return |    5.207
#                   Average Gain |    5.207
#                   Average Loss |      nan
#                     Max Return |    6.666
#                       Max Loss |      nan
#              Risk Reward Ratio |    5.207
#                Batting Average |    1.000
# 2021-05-20 00:00:00
# ['CARR', 'ALLE', 'CNC']
# [4.839299093588537, 4.758261640937445, 4.714473323953171]
# [*********************100%***********************]  1 of 1 completed
# 買値は44.16999816894531
# 売値は45.69499969482422
# [*********************100%***********************]  1 of 1 completed
# 買値は138.24000549316406
# 売値は140.14999389648438
# [*********************100%***********************]  1 of 1 completed
# 買値は72.12000274658203
# 売値は73.7300033569336
# 今回のリターン
# [3.452573215072241, 1.3816466488890233, 2.232391221626595]
#                 average Return |    2.356
#                   Average Gain |    2.356
#                   Average Loss |      nan
#                     Max Return |    3.453
#                       Max Loss |      nan
#              Risk Reward Ratio |    2.356
#                Batting Average |    1.000
# 2021-05-27 00:00:00
# ['EIX', 'K', 'GIS']
# [5.1664478918178585, 4.964788617344525, 4.8539664081996925]
# [*********************100%***********************]  1 of 1 completed
# 買値は55.86000061035156
# 売値は56.709999084472656
# [*********************100%***********************]  1 of 1 completed
# 買値は65.1500015258789
# 売値は66.62999725341797
# [*********************100%***********************]  1 of 1 completed
# 買値は62.45000076293945
# 売値は64.12999725341797
# 今回のリターン
# [1.5216585478582623, 2.271674125673173, 2.690146469102195]
#                 average Return |    2.161
#                   Average Gain |    2.161
#                   Average Loss |      nan
#                     Max Return |    2.690
#                       Max Loss |      nan
#              Risk Reward Ratio |    2.161
#                Batting Average |    1.000
# 2021-06-04 00:00:00
# ['EIX', 'CERN', 'EW']
# [4.664673981932283, 4.658473977125677, 4.6263054347330606]
# [*********************100%***********************]  1 of 1 completed
# 買値は56.709999084472656
# 売値は58.43000030517578
# [*********************100%***********************]  1 of 1 completed
# 買値は80.44000244140625
# 売値は81.0
# [*********************100%***********************]  1 of 1 completed
# 買値は95.83999633789062
# 売値は99.91000366210938
# 今回のリターン
# [3.0329769854890776, 0.696168002980424, 4.246668906235818]
#                 average Return |    2.659
#                   Average Gain |    2.659
#                   Average Loss |      nan
#                     Max Return |    4.247
#                       Max Loss |      nan
#              Risk Reward Ratio |    2.659
#                Batting Average |    1.000
# 2021-06-11 00:00:00
# ['HD', 'BBY', 'NSC']
# [4.816452418086231, 4.632930443418603, 4.577226440407302]
# [*********************100%***********************]  1 of 1 completed
# 買値は308.92999267578125
# 売値は305.25
# [*********************100%***********************]  1 of 1 completed
# 買値は114.55000305175781
# 売値は108.30000305175781
# [*********************100%***********************]  1 of 1 completed
# 買値は271.30999755859375
# 売値は263.010009765625
# 今回のリターン
# [-1.1912060217614928, -5.456132547788783, -3.0592266660487644]
#                 average Return |   -3.236
#                   Average Gain |      nan
#                   Average Loss |   -3.236
#                     Max Return |      nan
#                       Max Loss |   -5.456
#              Risk Reward Ratio |    0.000
#                Batting Average |    0.000
# 2021-06-18 00:00:00
# ['VFC', 'INCY', 'EIX']
# [5.190146795803045, 5.117924702276334, 5.115555711388267]
# [*********************100%***********************]  1 of 1 completed
# 買値は79.94999694824219
# 売値は82.44999694824219
# [*********************100%***********************]  1 of 1 completed
# 買値は84.41999816894531
# 売値は88.12000274658203
# [*********************100%***********************]  1 of 1 completed
# 買値は56.029998779296875
# 売値は57.02000045776367
# 今回のリターン
# [3.1269544658249826, 4.38285318394831, 1.7669136177682843]
#                 average Return |    3.092
#                   Average Gain |    3.092
#                   Average Loss |      nan
#                     Max Return |    4.383
#                       Max Loss |      nan
#              Risk Reward Ratio |    3.092
#                Batting Average |    1.000
# 2021-06-25 00:00:00
# ['VFC', 'HOLX', 'APH']
# [5.127868897881287, 4.942661685319536, 4.616644149110366]
# [*********************100%***********************]  1 of 1 completed
# 買値は82.44999694824219
# 売値は83.97000122070312
# [*********************100%***********************]  1 of 1 completed
# 買値は65.80000305175781
# 売値は69.22000122070312
# [*********************100%***********************]  1 of 1 completed
# 買値は68.27999877929688
# 売値は70.0
# 今回のリターン
# [1.843546790444539, 5.197565365240431, 2.5190410829717846]
#                 average Return |    3.187
#                   Average Gain |    3.187
#                   Average Loss |      nan
#                     Max Return |    5.198
#                       Max Loss |      nan
#              Risk Reward Ratio |    3.187
#                Batting Average |    1.000
# 2021-07-02 00:00:00
# ['ES', 'BLL', 'EIX']
# [4.989023320609501, 4.919619696144694, 4.860245819992233]
# [*********************100%***********************]  1 of 1 completed
# 買値は80.68000030517578
# 売値は82.37999725341797
# [*********************100%***********************]  1 of 1 completed
# 買値は82.0
# 売値は84.80999755859375
# [*********************100%***********************]  1 of 1 completed
# 買値は57.04999923706055
# 売値は57.810001373291016
# 今回のリターン
# [2.107085946717735, 3.426826290967977, 1.3321685300510255]
#                 average Return |    2.289
#                   Average Gain |    2.289
#                   Average Loss |      nan
#                     Max Return |    3.427
#                       Max Loss |      nan
#              Risk Reward Ratio |    2.289
#                Batting Average |    1.000
# [6.613571470167671, 4.2562998132470815, 6.634349428368735, 4.689546778273734, 6.778258955636803, 4.131927706734606, 4.628996391500147, 5.98776238137438, 4.060283954012389, 1.704330873291308, 3.583988247524069, 6.115292476378194, 2.997983199893691, 5.263274600224836, 2.01115063042534, 3.7509675924513117, 3.452797480746968, 4.517063477721273, 5.2068171907509635, 2.3555370285292865, 2.1611597142112102, 2.6586046315684397, -3.23552174519968, 3.092240422513859, 3.186717746218918, 2.2886935892455793]
# [3.8035420783004277, 4.085104631240431, -3.23552174519968, 6.778258955636803, -3.23552174519968, 1.2625798721029207, 0.9615384615384616]
#                 average Return |    3.804
#                   Average Gain |    4.085
#                   Average Loss |   -3.236
#                     Max Return |    6.778
#                       Max Loss |   -3.236
#              Risk Reward Ratio |    1.263
#                Batting Average |    0.962
# ========================
# 最終リターンは162.59679768275097

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
