# %%
import pandas as pd
import yfinance as yf


start = '2021-01-01'
end = '2021-04-01'
data = yf.download('BTC-USD', start, end, interval='60m') 
# data = yf.download('BTC-USD',interval='60m') 
print(data)
# data.to_csv('bitcoin/bitcoin.csv')
data.to_csv('bitcoin/bitcoin_60m.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                    Open          High           Low  \
# Datetime
# 2020-12-31 15:00:00+00:00  28403.164062  28827.904297  28403.164062
# 2020-12-31 16:00:00+00:00  28808.705078  28808.705078  28396.679688
# 2020-12-31 17:00:00+00:00  28413.082031  28714.220703  28413.082031
# 2020-12-31 18:00:00+00:00  28595.044922  28872.458984  28546.371094
# 2020-12-31 19:00:00+00:00  28887.412109  28997.074219  28804.308594
# ...                                 ...           ...           ...
# 2021-03-31 11:00:00+01:00  58197.367188  58340.156250  57747.722656
# 2021-03-31 12:00:00+01:00  57925.554688  58335.140625  57925.554688
# 2021-03-31 13:00:00+01:00  58277.925781  58497.347656  58081.449219
# 2021-03-31 14:00:00+01:00  58385.382812  58960.937500  58349.761719
# 2021-03-31 15:00:00+01:00  58819.289062  58953.554688  58722.328125
#
#                                   Close     Adj Close     Volume
# ...
