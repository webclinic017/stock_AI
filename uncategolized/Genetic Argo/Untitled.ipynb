# %%
import random
import numpy as np
from operator import attrgetter

def main():
    n_gene   = 2   # The number of genes.
    n_ind    = 300   # The number of individuals in a population.
    CXPB     = 0.5   # The probability of crossover.
    MUTPB    = 0.2   # The probability of individdual mutation.
    MUTINDPB = 0.05  # The probability of gene mutation.
    NGEN     = 40    # The number of generation loop.
    
    
    random.seed(64)
    #popはcreate_ind(n_gene)のリスト(長さrange(n_gene)分の0~1のどっちかの数のリスト)
    pop = create_pop(n_ind, n_gene)
    print(pop)
    #popを評価関数に置き換えたリスト
    set_fitness(evalOneMax, pop)
    print(set_fitness(evalOneMax, pop))
    
    best_ind = max(pop, key=attrgetter("fitness"))

  
    


class Individual(np.ndarray):
    """Container of a individual."""
    fitness = None
    def __new__(cls, a):
        return np.asarray(a).view(cls)

def create_ind(n_gene):
    """Create a individual."""
    #create_ind(n_gene)は長さrange(n_gene)分の0~1のどっちかの数のリスト
    return Individual([random.randint(1, 40) for i in range(n_gene)])



#popを作製
def create_pop(n_ind, n_gene):
    """Create a population."""
    pop = []
    for i in range(n_ind):
        #ind = create_ind(n_gene)は一つ前に作ったdef文　変数はn_gene
        ind = create_ind(n_gene)
        
        #popはcreate_ind(n_gene)のリスト(長さrange(n_gene)分の0~1のどっちかの数のリスト)
        pop.append(ind)
    return pop


def set_fitness(eval_func, pop):
    """Set fitnesses of each individual in a population."""
    
    #popの評価関数を算出し、popのそれぞれにkeyとして追加
    for i, fit in zip(range(len(pop)), map(eval_func, pop)):
        pop[i].fitness = fit

        
def evalOneMax(ind):
    """Objective function."""
    #create_ind(n_gene)は長さrange(n_gene)分の0~1のどっちかの数のリストの合計
    #評価関数
    return sum(ind)

  

def selTournament(pop, n_ind, tournsize):
    """Selection function."""
    chosen = []    
    for i in range(n_ind):
        #popはcreate_ind(n_gene)のリスト(長さrange(n_gene)分の0~1のどっちかの数のリスト)
        #popからランダムにトーナメントサイズ分選ぶ
        aspirants = [random.choice(pop) for j in range(tournsize)]
        #トーナメントに選んだpopから最も優れた個体をリストに格納
        chosen.append(max(aspirants, key=attrgetter("fitness")))
        
    return chosen




def cxTwoPointCopy(ind1, ind2):
    """Crossover function."""
    size = len(ind1)
    tmp1 = ind1.copy()
    tmp2 = ind2.copy()
    cxpoint1 = random.randint(1, size)
    cxpoint2 = random.randint(1, size-1)
    if cxpoint2 >= cxpoint1:
        cxpoint2 += 1
    else: # Swap the two cx points
        cxpoint1, cxpoint2 = cxpoint2, cxpoint1
    tmp1[cxpoint1:cxpoint2], tmp2[cxpoint1:cxpoint2] = tmp2[cxpoint1:cxpoint2].copy(), tmp1[cxpoint1:cxpoint2].copy()
    return tmp1, tmp2

if __name__ == "__main__":
    main()
# Out:
# [Individual([31,  8]), Individual([41, 40]), Individual([26, 35]), Individual([44,  2]), Individual([14, 18]), Individual([46, 41]), Individual([49, 13]), Individual([45, 50]), Individual([42, 10]), Individual([ 6, 27]), Individual([29, 13]), Individual([47,  2]), Individual([ 6, 26]), Individual([44,  1]), Individual([ 5, 12]), Individual([ 7, 38]), Individual([ 3, 38]), Individual([17, 15]), Individual([35, 13]), Individual([6, 2]), Individual([50, 30]), Individual([26, 14]), Individual([19, 48]), Individual([ 9, 36]), Individual([28, 23]), Individual([33, 20]), Individual([48, 24]), Individual([45, 32]), Individual([34, 12]), Individual([4, 1]), Individual([15, 30]), Individual([11, 14]), Individual([15,  4]), Individual([42, 18]), Individual([14, 44]), Individual([16,  2]), Individual([47, 20]), Individual([ 8, 11]), Individual([20, 15]), Individual([42, 37]), Individual([44, 16]), Individual([42, 16]), Individual([10, 40]), Individual([17, 28]), Individual([29, 20]), Individual([46, 24]), Individual([11, 18]), Individual([10, 12]), Individual([20,  3]), Individual([9, 4]), Individual([8, 8]), Individual([33,  4]), Individual([11, 22]), Individual([36, 17]), Individual([28, 31]), Individual([ 3, 44]), Individual([32, 21]), Individual([45, 33]), Individual([46,  3]), Individual([ 4, 48]), Individual([45, 35]), Individual([21, 44]), Individual([10, 49]), Individual([47, 49]), Individual([ 7, 33]), Individual([22, 20]), Individual([40, 33]), Individual([ 9, 26]), Individual([25, 24]), Individual([ 9, 21]), Individual([27,  1]), Individual([44,  1]), Individual([20, 43]), Individual([41, 40]), Individual([50, 11]), Individual([25, 12]), Individual([50, 34]), Individual([45, 15]), Individual([31, 18]), Individual([37, 29]), Individual([ 6, 21]), Individual([20, 17]), Individual([ 2, 28]), Individual([24, 48]), Individual([42,  7]), Individual([49,  8]), Individual([31, 42]), Individual([24, 48]), Individual([32,  7]), Individual([ 3, 35]), Individual([43, 33]), Individual([6, 2]), Individual([47, 39]), Individual([48, 33]), Individual([39,  8]), Individual([27, 25]), Individual([ 8, 25]), Individual([11, 34]), Individual([48, 10]), Individual([19, 23]), Individual([37,  8]), Individual([14, 43]), Individual([ 1, 22]), Individual([15, 10]), Individual([25,  6]), Individual([14, 34]), Individual([27,  9]), Individual([ 1, 19]), Individual([20, 27]), Individual([49,  9]), Individual([31,  2]), Individual([21, 33]), Individual([18, 28]), Individual([48, 40]), Individual([49, 30]), Individual([22,  9]), Individual([14, 35]), Individual([14, 22]), Individual([17, 36]), Individual([12, 32]), Individual([ 3, 12]), Individual([ 1, 22]), Individual([38, 44]), Individual([22, 41]), Individual([42, 11]), Individual([14, 42]), Individual([49, 46]), Individual([19, 35]), Individual([26, 18]), Individual([20,  1]), Individual([41, 27]), Individual([18, 29]), Individual([34, 23]), Individual([ 2, 50]), Individual([ 4, 23]), Individual([28, 17]), Individual([25,  2]), Individual([46, 11]), Individual([49, 31]), Individual([ 5, 30]), Individual([27,  3]), Individual([36, 33]), Individual([34, 36]), Individual([10, 25]), Individual([29, 30]), Individual([49, 29]), Individual([30,  2]), Individual([24, 25]), Individual([48, 18]), Individual([34, 34]), Individual([1, 9]), Individual([14, 44]), Individual([14, 28]), Individual([ 2, 46]), Individual([25, 38]), Individual([16, 29]), Individual([ 5, 48]), Individual([ 2, 21]), Individual([36, 10]), Individual([36, 42]), Individual([50, 49]), Individual([15, 25]), Individual([34, 19]), Individual([16, 43]), Individual([43, 18]), Individual([33, 45]), Individual([33, 45]), Individual([33, 11]), Individual([28,  4]), Individual([20,  5]), Individual([37,  4]), Individual([25, 28]), Individual([31, 18]), Individual([12, 31]), Individual([32, 28]), Individual([34, 47]), Individual([21, 28]), Individual([21,  7]), Individual([24, 49]), Individual([40, 36]), Individual([37, 30]), Individual([37, 28]), Individ ...
# None
